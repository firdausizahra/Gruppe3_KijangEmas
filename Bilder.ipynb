# %% [markdown]
# ![Kijang_Emas.jpg](attachment:Kijang_Emas.jpg)

# %% [markdown]
# ![LSTM_Aufbau.PNG](attachment:LSTM_Aufbau.PNG)

# %% [markdown]
# ![LSTM_Aufbau_2.PNG](attachment:LSTM_Aufbau_2.PNG)

# %% [markdown]
# ![LSTM_Aufbau_3.PNG](attachment:LSTM_Aufbau_3.PNG)

# %% [markdown]
# ![LSTM_Aufbau_4.PNG](attachment:LSTM_Aufbau_4.PNG)

# %% [markdown]
# ![LSTM_Aufbau_5.PNG](attachment:LSTM_Aufbau_5.PNG)

# %% [markdown]
# ![LSTM_Aufbau_6.PNG](attachment:LSTM_Aufbau_6.PNG)

# %% [markdown]
# <b>Quelle</b>
# * http://materiaislamica.com/index.php/Kijang_Emas_Bullion_(Gold_Coin)
# * http://colah.github.io/posts/2015-08-Understanding-LSTMs/
